# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F
from tqdm import tqdm
import os
import re
import sys
import time
import logging
import tempfile
from collections import Counter
from typing import List, Tuple
from tqdm import tqdm

import numpy as np
import pandas as pd

import rdkit
from rdkit import Chem
from rdkit.Chem import MolFromSmiles, MolToSmiles, CanonSmiles

import deepchem as dc
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_validate
from scipy.sparse import csr_matrix, lil_matrix

import atomInSmiles as ais
import json

# %%
#create teh vocabulary for all the words in the SMILES

class CreateVocab():
    def __init__(self, datasets):
        """
        Initialize the CreateVocab object with multiple datasets.

        :param datasets: List of datasets (strings) to build the vocabulary from.
        """
        self.stoi = {}
        self.itos = {}
        self.pad_token = '*'
        self.build_vocab(datasets)
        self.vocab_size = len(self.stoi)

    def build_vocab(self, datasets):
        """
        Build the vocabulary from the datasets.

        :param datasets: List of datasets (strings) to build the vocabulary from.
        """
        all_words = set()
        n = 1
        for dataset in datasets:
            dataset = self.preprocess_smile(dataset)
            name_d = str(n) + 'process_data'
            with open(name_d, 'w') as f:
                f.write(dataset)
            n += 1
            all_words.update(dataset.split())
        all_words = sorted(all_words)
        self.stoi = {word: i for i, word in enumerate(all_words)}
        self.itos = {i: word for word, i in self.stoi.items()}

    def preprocess_smile(self, dataset):

        #data = []
        data = ""
        for smile in dataset:
            sections = self.separate(smile)
            all_sections = self.show_sections(smile, sections)
            d = " ".join(all_sections)
            d = d.replace('\\n', '').replace('(', ' (').replace(')', ') ').replace('[', ' [').replace(']', '] ').replace('  ', ' ')
            d = d + '* '
            d = d.replace('  ', ' ')
            data += d
        #print(data)
        return data

    
    def separate(self, s):
        stack = []
        sections = []
        for i, c in enumerate(s):
            if c in ['(', '[']:
                stack.append((c, i))
            elif c in [')', ']']:
                while stack:
                    opening, start = stack[-1]  # Peek at the top of the stack
                    if (opening == '(' and c == ')') or (opening == '[' and c == ']'):
                        stack.pop()  # Remove the matching opening bracket
                        sections.append((start, i))
                        break
                    else:
                        stack.pop()  # Remove the non-matching opening bracket

        # Filter out overlapping sections
        non_overlapping_sections = []
        last_end = -1
        for start, end in sorted(sections, key=lambda x: x[0]):
            if start > last_end:
                non_overlapping_sections.append((start, end))
                last_end = end

        return non_overlapping_sections


    def show_sections(self, s, sections):
        all_sections = []
        last_end = 0  # To keep track of the last section's end index

        for start, end in sections:
            if start > last_end:
                # Add the section between the last end and this start
                all_sections.append(s[last_end:start])
            # Add the section within the current parenthesis/bracket
            all_sections.append(s[start:end+1])
            last_end = end + 1  # Update the last end index

        # Handle any remaining section after the last parenthesis/bracket
        if last_end < len(s):
            all_sections.append(s[last_end:])

        return all_sections
    
    def encode(self, text):
        """
        Encode the input SMILES string into a tensor of integers.

        :param smile: Input SMILES string.
        :return: Tensor of integers.
        """
        return [self.stoi[word] for word in text.split()]
    
    def decode(self, tensor):
        """
        Decode the input tensor of integers into a SMILES string.

        :param tensor: Input tensor of integers.
        :return: SMILES string.
        """
        return ''.join([self.itos[i] for i in tensor])
    

    

smile_1 = pd.read_csv('smile_1.csv')['smiles']
smile_2 = pd.read_csv('smile_2.csv')['smiles']
smile_3 = pd.read_csv('smile_3.csv')['canonical_smiles']


# Combine processed datasets
#datasets = [smile_1, smile_2, smile_3]
datasets = [smile_3]


# Create vocabulary
vocab = CreateVocab(datasets)

# %%
#open 3process_data and read the data
with open('3process_data', 'r') as f:
    text = f.read()

# %%
vocab = open('vocab_words.json', 'w')
json.dump(vocab.stoi, vocab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 vocab = open('vocab_words.json', 'w')
# ----> 2 json.dump(vocab.stoi, vocab)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'stoi'

# %%
#save the vocabulary
with open('vocab_words.json', 'w') as f:
    json.dump(vocab.stoi, f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 #save the vocabulary
#       2 with open('vocab_words.json', 'w') as f:
# ----> 3     json.dump(vocab.stoi, f)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'stoi'

# %%
print(vocab.stoi)
# Out:
# {'#': 0, '#C': 1, '#CC)': 2, '#N': 3, '#N)': 4, '%11': 5, '%118)': 6, '%11=C': 7, '%11C': 8, '%12%13)': 9, '%14': 10, '(': 11, '(#CC1=CCCCC1)': 12, '(#CCN1CCCC1)': 13, '(#CCN1CCCCCC1)': 14, '(#Cc1ccccc1)': 15, '(#Cc1cncnc1)': 16, '(-': 17, '(-c1cc': 18, '(-c1cc3c': 19, '(-c1ccc': 20, '(-c1cccc': 21, '(-c1ccccc1)': 22, '(-c1ccccc1Cl)': 23, '(-c1ccccc1F)': 24, '(-c1ccccn1)': 25, '(-c1cccnc1)': 26, '(-c1cccs1)': 27, '(-c1csc': 28, '(-c1nc': 29, '(-c2': 30, '(-c2c': 31, '(-c2c3c': 32, '(-c2c3c4n': 33, '(-c2c3ccc': 34, '(-c2c3ccccc3': 35, '(-c2c3ccccc3c': 36, '(-c2c3ccccc3c3n2CCS3)': 37, '(-c2c3ccccc3c3sc4ccccc4n23)': 38, '(-c2c3ccccc3nc3ccccc23)': 39, '(-c2c3oc4c': 40, '(-c2c3oc4cc': 41, '(-c2c3sc': 42, '(-c2cc': 43, '(-c2cc3': 44, '(-c2cc3c': 45, '(-c2cc3c4c': 46, '(-c2cc3c4ccccc4nc': 47, '(-c2cc3c4ccccc4oc4nc': 48, '(-c2cc3c4nn': 49, '(-c2cc3c4nnc': 50, '(-c2cc3cc': 51, '(-c2cc3ccc': 52, '(-c2cc3ccc4c': 53, '(-c2cc3ccc4cccnc4c3o2)': 54, '(-c2cc3cccc': 55, '(-c2cc3ccccc3': 56, '(-c2cc3ccccc3cc2OC)': 57, '(-c2cc3ccccc3n2C)': 58, '(-c2cc3ccccc3n2CC': 59, '(-c2cc3ccccc3n2Cc2ccc': 60, '(-c2cc3ccccc3n2N=O)': 61, '(-c2cc3ccccc3nc2O)': 62, '(-c2cc3ccccc3o2)': 63, '(-c2cc3ccccc3oc2=O)': 64, '(-c2cc3ccccc3s2)': 65, '(-c2cc3cccccc-3n2)': 66, '(-c2cc3ccccn3n2)': 67, '(-c2cc3cccnc3n2CC': 68, '(-c2cc3cccnc3n2CCC': 69, '(
C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (CC1CCCCC1) NC (=O) c1cccnc1) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (CC2CCCCC2) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cn1* COC (=O) N [C@H] (C (=O) NCCCC [C@H] (CO) N (CC (C) C) S (=O) (=O) c1cccc2cccnc12) C (c1ccccc1) c1ccccc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Cl) NC (=O) c1ccncc1) S (=O) (=O) c1ccc (N) cc1* Cc1ncccc1C (=O) N [C@@H] (Cc1ccccc1Cl) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (CC1=C (Br) CCC=C1) NC (=O) N1CCOCC1) S (=O) (=O) c1ccc2c (c1) OCCO2* COC (=O) N [C@H] (C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc2c (c1) CCO2) C (C1=CC=CCC1) c1ccccc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) N1CCOCC1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc2c (c1) CCO2* COC (=O) N [C@H] (C (=O) NCCCC [C@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc2c (c1) N (C) CCO2) C (c1ccccc1) c1ccccc1* Cc1cccnc1C (=O) N [C@@H] (Cc1ccccc1Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cc1O* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) OCc1ccncc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccc2ccccc2c1) NS (=O) (=O) c1ccc2c (c1) OCCC2C) S (=O) (=O) c1ccc (N) cc1* CCC (=O) NC (=O) N (C) CC (=O) N [C@@H] (Cc1ccc2ccccc2c1) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccc2ccccc2c1) NCc1ccccn1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NS (=O) (=O) c1cccs1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* CN [C@H] (C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) C1C=CC=CC1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) NCC1=CCCN=C1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) NCc1ccncc1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2C) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cc1O* COC (=O) N [C@H] (C (=O) NCCCCC (C (N) =O) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) c1ccccc1* COC (=O) N [C@H] (C (=O) NCCCC [C@@H] (CO) N (Cc1cccnc1) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) c1ccccc1* Cc1ncccc1C (=O) N [C@@H] (Cc1ccccc1Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cn1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (Cc1ccccc1Br) NC (=O) c1ccc2c (c1) OCO2) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) C (Cc1ccccc1Br) NC (=O) c1ccncc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) C1=NCC (C) N=C1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) c1cnccn1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O)  ...

# %%
encoded_text = vocab.encode(text)

# Train and test splits
data = torch.tensor(encoded_text, dtype=torch.long)

# Split the data into training and validation sets randomly
train_size = int(0.9 * len(data))
val_size = len(data) - train_size
train_data, val_data = torch.utils.data.random_split(data, [train_size, val_size])

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 1200
eval_interval = 10
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 100
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.2 #Change of dropout form 0 to 0.2
# ------------

torch.manual_seed(1337)
vocab_size = len(vocab.stoi)

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
model = BigramLanguageModel()

# %%
model_state_path = "Only3_BPS.pkl"
model.load_state_dict(torch.load(model_state_path))
# Out:
# <All keys matched successfully>

# %%
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Out:
# 0.218501 M parameters

# %%
train_losses = []
val_losses = []


for iter in range(max_iters):
    # Evaluate the loss periodically
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # Get a batch of data
    xb, yb = get_batch('train')

    # Forward pass and loss computation
    logits, loss = model(xb, yb)

    # Backpropagation
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
# Out:
# step 0: train loss 5.0295, val loss 5.0621
# step 10: train loss 4.0318, val loss 4.1856
# step 20: train loss 3.7997, val loss 3.9437
# step 30: train loss 3.7395, val loss 3.8846
# step 40: train loss 3.6995, val loss 3.8730
# step 50: train loss 3.6574, val loss 3.9207
# step 60: train loss 3.6038, val loss 3.9544
# step 70: train loss 3.5284, val loss 4.0457
# step 80: train loss 3.4473, val loss 4.0226
# step 90: train loss 3.3600, val loss 4.0847
# step 100: train loss 3.2580, val loss 4.1353
# step 110: train loss 3.1636, val loss 4.1452
# step 120: train loss 3.0726, val loss 4.1738
# step 130: train loss 2.9684, val loss 4.2209
# step 140: train loss 2.8948, val loss 4.3249
# step 150: train loss 2.8253, val loss 4.4130
# step 160: train loss 2.7412, val loss 4.3536
# step 170: train loss 2.6612, val loss 4.4740
# step 180: train loss 2.5891, val loss 4.5147
# step 190: train loss 2.5263, val loss 4.5896
# step 200: train loss 2.4466, val loss 4.6496
# step 210: train loss 2.3537, val loss 4.6711
# step 220: train loss 2.2734, val loss 4.8094
# step 230: train loss 2.1810, val loss 4.8464
# step 240: train loss 2.0837, val loss 4.9304
# step 250: train loss 1.9944, val loss 5.0238
# step 260: train loss 1.9150, val loss 5.0390
# step 270: train loss 1.7864, val loss 5.1343
# step 280: train loss 1.7063, val loss 5.1811
# step 290: train loss 1.6212, val loss 5.2150
# step 300: train loss 1.5280, val loss 5.3533
# step 310: train loss 1.4589, val loss 5.4048
# step 320: train loss 1.3624, val loss 5.5523
# step 330: train loss 1.2785, val loss 5.6352
# step 340: train loss 1.2042, val loss 5.7650
# step 350: train loss 1.1456, val loss 5.8361
# step 360: train loss 1.0674, val loss 5.8550
# step 370: train loss 1.0210, val loss 5.8948
# step 380: train loss 0.9569, val loss 6.0043
# step 390: train loss 0.8927, val loss 6.0520
# step 400: train loss 0.8317, val loss 6.1692
# step 410: train loss 0.7860, val loss 6.3085
# step 420: train loss 0.7441, val loss 6.2792
# step 430: train loss 0.6843, val loss 6.4269
# step 440: train loss 0.6549, val loss 6.5796
# step 450: train loss 0.6281, val loss 6.6490
# step 460: train loss 0.6061, val loss 6.6536
# step 470: train loss 0.5743, val loss 6.7371
# step 480: train loss 0.5288, val loss 6.6966
# step 490: train loss 0.5268, val loss 6.9049
# step 500: train loss 0.5023, val loss 6.9240
# step 510: train loss 0.4701, val loss 7.0254
# step 520: train loss 0.4649, val loss 7.1051
# step 530: train loss 0.4528, val loss 7.0998
# step 540: train loss 0.4312, val loss 7.1499
# step 550: train loss 0.4171, val loss 7.2500
# step 560: train loss 0.4080, val loss 7.2378
# step 570: train loss 0.3969, val loss 7.2059
# step 580: train loss 0.3911, val loss 7.2007
# step 590: train loss 0.3744, val loss 7.3622
# step 600: train loss 0.3671, val loss 7.3418
# step 610: train loss 0.3568, val loss 7.4220
# step 620: train loss 0.3446, val loss 7.5412
# step 630: train loss 0.3386, val loss 7.5627
# step 640: train loss 0.3279, val loss 7.5224
# step 650: train loss 0.3261, val loss 7.5741
# step 660: train loss 0.3269, val loss 7.8180
# step 670: train loss 0.3124, val loss 7.8137
# step 680: train loss 0.3119, val loss 7.8657
# step 690: train loss 0.3029, val loss 7.8185
# step 700: train loss 0.2991, val loss 7.8491
# step 710: train loss 0.2948, val loss 7.8709
# step 720: train loss 0.2836, val loss 7.9397
# step 730: train loss 0.2905, val loss 7.9476
# step 740: train loss 0.2778, val loss 7.9542
# step 750: train loss 0.2707, val loss 8.0091
# step 760: train loss 0.2689, val loss 7.9461
# step 770: train loss 0.2665, val loss 8.1062
# step 780: train loss 0.2582, val loss 8.2355
# step 790: train loss 0.2545, val loss 8.1330
# step 800: train loss 0.2500, val loss 8.0138
# step 810: train loss 0.2441, val loss 8.1258
# step 820: train loss 0.2406, val loss 8.1705
# step 830: train loss 0.2432, val loss 8.3551
# step 840: train loss 0.2490, val loss 8.2395
# step 850: train loss 0.2364, val loss 8.3710
# step 860: train loss 0.2314, val loss 8.2940
# step 870: train loss 0.2337, val loss 8.2334
# step 880: train loss 0.2260, val loss 8.4409
# step 890: train loss 0.2234, val loss 8.4113
# step 900: train loss 0.2260, val loss 8.4581
# step 910: train loss 0.2199, val loss 8.5090
# step 920: train loss 0.2167, val loss 8.5489
# step 930: train loss 0.2174, val loss 8.5205
# step 940: train loss 0.2113, val loss 8.4217
# step 950: train loss 0.2142, val loss 8.6295
# step 960: train loss 0.2090, val loss 8.4599
# step 970: train loss 0.2059, val loss 8.5453
# step 980: train loss 0.2019, val loss 8.6076
# step 990: train loss 0.2025, val loss 8.6865
# step 1000: train loss 0.2018, val loss 8.5107
# step 1010: train loss 0.1973, val loss 8.5240
# step 1020: train loss 0.2085, val loss 8.7811
# step 1030: train loss 0.1949, val loss 8.5801
# step 1040: train loss 0.2070, val loss 8.7764
# step 1050: train loss 0.1954, val loss 8.6287
# step 1060: train loss 0.1900, val loss 8.5923
# step 1070: train loss 0.1916, val loss 8.8198
# step 1080: train loss 0.1902, val loss 8.8398
# step 1090: train loss 0.1823, val loss 8.8228
# step 1100: train loss 0.1850, val loss 8.9996
# step 1110: train loss 0.1772, val loss 8.9977
# step 1120: train loss 0.1803, val loss 8.9253
# step 1130: train loss 0.1894, val loss 8.9750
# step 1140: train loss 0.1845, val loss 8.9488
# step 1150: train loss 0.1771, val loss 9.1761
# step 1160: train loss 0.1764, val loss 9.1072
# step 1170: train loss 0.1755, val loss 9.1255
# step 1180: train loss 0.1754, val loss 8.9862
# step 1190: train loss 0.1757, val loss 9.2019
# step 1199: train loss 0.1767, val loss 9.1801

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss', color='purple')
plt.plot(val_losses, label='Validation Loss', color='green')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
def separate(s):
    stack = []
    sections = []
    for i, c in enumerate(s):
        if c in ['(', '[']:
            stack.append((c, i))
        elif c in [')', ']']:
            while stack:
                opening, start = stack[-1]  # Peek at the top of the stack
                if (opening == '(' and c == ')') or (opening == '[' and c == ']'):
                    stack.pop()  # Remove the matching opening bracket
                    sections.append((start, i))
                    break
                else:
                    stack.pop()  # Remove the non-matching opening bracket

    # Filter out overlapping sections
    non_overlapping_sections = []
    last_end = -1
    for start, end in sorted(sections, key=lambda x: x[0]):
        if start > last_end:
            non_overlapping_sections.append((start, end))
            last_end = end

    return non_overlapping_sections


def show_sections(s, sections):
    all_sections = []
    last_end = 0  # To keep track of the last section's end index

    for start, end in sections:
        if start > last_end:
            # Add the section between the last end and this start
            all_sections.append(s[last_end:start])
        # Add the section within the current parenthesis/bracket
        all_sections.append(s[start:end+1])
        last_end = end + 1  # Update the last end index

    # Handle any remaining section after the last parenthesis/bracket
    if last_end < len(s):
        all_sections.append(s[last_end:])

    return all_sections

smiles = smiles 
s = smiles[0]
sections = separate(s)
all_sections = show_sections(s, sections)
" ".join(all_sections)
# Out:
# 'CC (C) (C) c1ccc2occ (CC(=O)Nc3ccccc3F) c2c1\n'

# %%
def separate(s):
    stack = []
    sections = []
    for i, c in enumerate(s):
        if c in ['(', '[']:
            stack.append((c, i))
        elif c in [')', ']']:
            while stack:
                opening, start = stack[-1]  # Peek at the top of the stack
                if (opening == '(' and c == ')') or (opening == '[' and c == ']'):
                    stack.pop()  # Remove the matching opening bracket
                    sections.append((start, i))
                    break
                else:
                    stack.pop()  # Remove the non-matching opening bracket
    # Filter out overlapping sections
    non_overlapping_sections = []
    last_end = -1
    for start, end in sorted(sections, key=lambda x: x[0]):
        if start > last_end:
            non_overlapping_sections.append((start, end))
            last_end = end

    return non_overlapping_sections 



def show_sections(s, sections):
    all_sections = []
    last_end = 0  # To keep track of the last section's end index

    for start, end in sections:
        if start > last_end:
            # Add the section between the last end and this start
            all_sections.append(s[last_end:start])
        # Add the section within the current parenthesis/bracket
        all_sections.append(s[start:end+1])
        last_end = end + 1  # Update the last end index

    # Handle any remaining section after the last parenthesis/bracket
    if last_end < len(s):
        all_sections.append(s[last_end:])

    return all_sections

# %%
smiles_1 = pd.read_csv('smile_1.csv')
smiles = smiles_1['smiles']

# %%
text = ""

for i in tqdm(range(len(smiles))):
    sections = separate(smiles[i])
    all_sections = show_sections(smiles[i], sections)
    text += " ".join(all_sections)
    text.replace("\n", "")
    text = text.replace('(', ' (').replace(')', ') ').replace('[', ' [').replace(']', '] ').replace('  ', ' ')
    text += "* "
# Out:
#   0%|          | 0/249455 [00:00<?, ?it/s]
#  40%|███▉      | 99154/249455 [2:18:11<31:26:17,  1.33it/s]

# %%
#save text 

with open('smiles_1_processed.txt', 'w') as f:
    f.write(text)

# %%
#text = text.replace("\n", "")

print(text)
# Out:
# CC (C) CN (Sc1ccc2c (c1) CCO2) [C@H] (CO) CCCCNC (=O) [C@@H] (Cc1cccc2ccccc12) NC (=O) N1CCOCC1* CC (C) CN (Sc1ccc2c (c1) OCCO2) [C@H] (CO) CCCCNC (=O) [C@@H] (Cc1cccc2ccccc12) NC (=O) N1CCOCC1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) N1CCOCC1) S (=O) (=O) c1ccc2c (c1) CCO2* Cc1c (O) cccc1C (=O) N [C@@H] (Cc1ccccc1Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) c1cccc (=O) [nH] 1) S (=O) (=O) c1ccc (N) cc1* Cc1ccccc1C [C@H] (NC (=O) c1cccnc1) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* O=C (O) CNC (=O) c1c (=O) oc (O) c2cc (Br) ccc12* C [C@H] (NC (=O) c1c (=O) oc (O) c2cccc (-c3cccc (C (F) (F) F) c3) c12) C (=O) O* Cc1ccccc1C [C@H] (NC (=O) c1cccc (C) c1O) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* COC (=O) N [C@@H] (CC1CCCCC1) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (CC1CCCCC1) NC (=O) c1cccnc1) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (CC2CCCCC2) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cn1* COC (=O) N [C@H] (C (=O) NCCCC [C@H] (CO) N (CC (C) C) S (=O) (=O) c1cccc2cccnc12) C (c1ccccc1) c1ccccc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Cl) NC (=O) c1ccncc1) S (=O) (=O) c1ccc (N) cc1* Cc1ncccc1C (=O) N [C@@H] (Cc1ccccc1Cl) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (CC1=C (Br) CCC=C1) NC (=O) N1CCOCC1) S (=O) (=O) c1ccc2c (c1) OCCO2* COC (=O) N [C@H] (C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc2c (c1) CCO2) C (C1=CC=CCC1) c1ccccc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) N1CCOCC1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc2c (c1) CCO2* COC (=O) N [C@H] (C (=O) NCCCC [C@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc2c (c1) N (C) CCO2) C (c1ccccc1) c1ccccc1* Cc1cccnc1C (=O) N [C@@H] (Cc1ccccc1Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cc1O* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) OCc1ccncc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccc2ccccc2c1) NS (=O) (=O) c1ccc2c (c1) OCCC2C) S (=O) (=O) c1ccc (N) cc1* CCC (=O) NC (=O) N (C) CC (=O) N [C@@H] (Cc1ccc2ccccc2c1) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccc2ccccc2c1) NCc1ccccn1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NS (=O) (=O) c1cccs1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* CN [C@H] (C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) C1C=CC=CC1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) NCC1=CCCN=C1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (NC (=O) NCc1ccncc1) C (c1ccccc1) c1ccccc1) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2C) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cc1O* COC (=O) N [C@H] (C (=O) NCCCCC (C (N) =O) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) c1ccccc1* COC (=O) N [C@H] (C (=O) NCCCC [C@@H] (CO) N (Cc1cccnc1) S (=O) (=O) c1ccc (N) cc1) C (c1ccccc1) c1ccccc1* Cc1ncccc1C (=O) N [C@@H] (Cc1ccccc1Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c1ccc (N) cc1* Cc1ccc (C (=O) N [C@@H] (Cc2ccccc2Br) C (=O) NCCCC [C@@H] (CO) N (CC (C) C) S (=O) (=O) c2ccc (N) cc2) cn1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@@H] (Cc1ccccc1Br) NC (=O) c1ccc2c (c1) OCO2) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) C (Cc1ccccc1Br) NC (=O) c1ccncc1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) C1=NCC (C) N=C1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O) [C@H] (Cc1ccccc1Br) NC (=O) c1cnccn1) S (=O) (=O) c1ccc (N) cc1* CC (C) CN ( [C@H] (CO) CCCCNC (=O)  ...

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)

# %%
val = vocab.decode(m.generate(context, max_new_tokens=6000)[0].tolist())

# %%
print(val)
# Out:
# (cc1*NCCCCcc1*C)(C)CN(C)(=O)[C@H]OCO2)CCCc1ccc(c1)(CC(Cc1cccc2ccccc12)NS(Cc1ccccc1Br)(CO)NC(CO)[C@@H][C@@H](Cc1ccc2cS[C@H]c1cccCCO2)oc(=O)c2ccc(O)CC(C#N)cc1)(C#N)ocCc1ccccc1C[C@H](=O)c2cccc2)C)CNcc1*S(OC)C(NCS((c
#  '[C@@H](=O)(N2CCC(=O)N1CCOCC1)(NCSn1',
#  'CCCCNCC1=NCC(N)[C@H]=O)c1ccc(=O)(=O)c1cccC)c1ccc[C@@H](=O)[C@H](=O)c1ccc[C@@H](=O)c1ccc(CO)(=O)CNS[C@@H](N)NCCCC[C@@H](C)c1',
#  '(=O)(=O)(=O)(CO)(C#N)(N)(N)(=O)(=O)(=O)Sn1',
#  'Sn1',
#  'SCNc1cccC)cc1',
#  '(C#N)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCC(N)C)(C)CN(CCCCNCCN(N)(CO)(=O)CC(=O)(=O)cc2)N(C)cc1',
#  'cc1',
#  '(=O)NCNCCCCcc1',
#  'C)C(Br)NCc1ccccn1)(=O)(CO)(C#N)(C(C(Sc1ccc2cCCCCCC(=O)[C@@H]CN(C[nH](CO)(C)(N)[C@H](C)(N)Sn1',
#  'SCNc1ccccc12',
#  'C)CCcc1',
#  'SCN(C#N)(=O)C(Br)NCc1ccccn1)(=O)(=O)(=O)C)CCc1ccc[C@H](cc1',
#  'NCCCC(=O)CCCCNCCCO2',
#  'c1cccCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NC(CO)(=O)NC[C@@H]C)c1O)CC(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCCCNCC1=NCC(N)[C@H]ccc2cCNC(=O)(=O)(CC1CCCCC1)SC(CCC(C)cc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1cc(N)(C)(CCC(N)(CC(Cc1cccc2ccccc12)NS(CO)[C@@H](C)NSCCCCNC(N)[C@H](=O)(=O)(CC(=O)(=O)CNC)(=O)cc1',
#  'NCCCCcc1',
#  'C)(C)CN(CCCCNCcc1',
#  'cc1',
#  'C)(=O)c1cccCc1ccnc2c1NCcc1',
#  '(CO)cCcc1',
#  '(C(Sc1ccc2cCC(=O)[C@@H]ccc12',
#  'CCC=C1)(=O)CCCCNC[C@@H]C(CC(NCOCc1ccncc1)NS(C)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)N[C@H]c1ccccc1',
#  '(=O)(=O)(N)CNCc1ccc(NC(C)Cc1Oc1ncCN(C)C)nc(c1)S(=O)(=O)(Nc2ccc(Nc2ccc(Nc2ccc(Nc2cccN1CCOCC1',
#  '(Oc2cN[C@H](Nc2cccNCCCCNC(C#N)[C@@H](=O)[C@@H][C@H](=O)(=O)(F)CN(CCF)C(=O)(=O)c2=O)(=O)(C)(=O)[C@H](SN(F)C(=O)(Cc2ccccc2C)(=O)(C)[C@@H](Cc1ccc2ccccc2c1)(=O)[C@@H](Cc1cccc2ccccc12)CCCCNC[C@@H](Cc1cccc2ccccc12)CCCCNCcc2SCCCCNC(N)NCCCC[C@@H](C)c1',
#  '(=O)(=O)(=O)(CO)(C#N)(N)(N)(=O)(=O)Sn1',
#  'Sn1',
#  'S(CO)(C[C@H](=O)cc1',
#  '(=O)CNC)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCCcc1',
#  'CCCCNCC)(C)CN(CCCCNCCN(N)(CO)(=O)c1ccc[C@@H](=O)(=O)CN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1',
#  '[C@@H](=O)(N2CCC(=O)N1CCOCC1)(NCS[C@@H](C)(C[nH](=O)(=O)c1ccc(CC(=O)(O)c1ccc(C(C#N)(=O)C)(C[C@H](=O)CCCCNCcc(=O)cc1',
#  'C)(Oc2ccccc2OCCn2ccccc1',
#  'C)(C(Sc1ccc2cCC(=O)[C@@H]C(Br)NCc1ccccn1)(=O)(=O)(=O)(=O)C)(cc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(=O)(=O)(N)(CO)cc3)cc2)C)cc1',
#  'NCCCCcc1',
#  '(C#N)c1ccc(NCOCc1ccncc1)NS(CCCCNCCCO2',
#  'c1cccCc1ccnc2c1NCcc1',
#  '(=O)(=O)N(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H][C@@H]CCC(C)cc3)cc2)(=O)c1ccc2cCCCCNC(=O)c1Oc1ccNCC1=CCCN=C1)(c1ccccc1)N[C@H](Cc1ccccc1Br)(=O)(CC(CC(CCCc1cS(C)(=O)c1Oc1cc[C@@H]CCC(C)[C@H](c1)cn1',
#  '(CCCCNCCN(=O)cc1',
#  'NCCCCcc1',
#  'CCCCNC(=O)CCc1ccccc1Cc1ccccc1)(=O)cc1)cc1',
#  '(=O)(=O)(CO)cc3)cc2)(=O)(C(Sc1ccc2cCC(=O)c1ccc2c(=O)(S(CO)(CO)CCCC(=O)(=O)[C@@H][C@@H][C@@H]C)(Oc2ccccc2OCCn2ccc(F)(N)NCCCC(=O)CC(=O)CCc1ccc[C@H](=O)(=O)(=O)NCCCC(=O)CCCCNC((=O)CC(=O)CC(=O)cc2)[C@H](N)(CO)c1ccc(=O)(=O)C)CNcc1',
#  '[C@@H]ccc12',
#  'CCC=C1)(=O)CCCCNCC)C(Br)NCc1ccccn1)(=O)c1ccccc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  'CCO2',
#  '(C#CC2CC2)c2ccc(C)CCCCNC(=O)[C@@H](=O)c1cccCc1ccnc2c1NCcc1',
#  '(CO)c1ccccc1',
#  '(C)(Oc2ccccc2OCCn2ccc(C)nccc1',
#  '(CO)CN(C)CN((C)(=O)N(C)(=O)S(CCc1cc(=O)[C@@H](c1ccccc1',
#  '(OC)CN(=O)(Cc2ccccc2C)(CO)cCcc1',
#  '(C(Sc1ccc2cCC(C)(c1ccccc1)Sc2ccccCC(SN(Cc1ccc2c(=O)(=O)CCCCNCSN(F)C(=O)CC(Cc1ccccc1Br)(CO)(O)(CCC(C)(N)(NSNCc1ccncc1)(Br)C2)(c1)NCCCC(=O)(=O)CC(=O)(=O)Sn1',
#  'c1ccccc1',
#  'COCNNCCCCC[C@H](c1ccc[C@H](=O)CCCCNC(CO)[C@H](=O)(=O)cc1',
#  '(=O)cc1',
#  '(=O)N(C)CN(C)(=O)[C@H](Cc1cccnc1)O1',
#  '(F)(N)(c1)(=O)(=O)(=O)c1ccc(CO)[C@@H]SCOc1cc2ccN(N)[nH](CO)[C@@H](C)c1ccc2cCOCNC(=O)(N)CCO2',
#  'c1ccc=O)(CO)(CCNc1ccc(C#N)(Cc1ccccc1Br)(CO)(=O)(c1)SN(Cc1ccc2ccccc2c1)[C@H](CO)(N[C@H](N)CN[C@@H]n1',
#  '(=O)CNc1ccccc12',
#  'C)cc1',
#  'CNcc1',
#  'CN(C#N)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCCN(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(N)(c1ccccc1)c1ccc(=O)(CC1CCCCC1)SC(CCCcc1',
#  '(C)cc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1cc(N)(C)(CC(=O)(=O)(=O)(=O)NSn1',
#  'CCCCNCcc[C@@H]ccc12',
#  'CCC=C1)(=O)cc1',
#  'NCCCCcc1',
#  'c1cnccn1)(=O)CCCCNCC)C(Br)NCc1ccccn1)(=O)(=O)c1ccc[C@H]c1cccc(=O)C)(cc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(CO)c1ccccc1',
#  '(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2cccN(N)C)c1O)CC(=O)(Sc1ccc2cCC(=O)(=O)(C1=CC=CCC1)(=O)(=O)CCCCNC[C@@H]C(Br)NCc1ccccn1)(=O)(=O)(CO)[C@H]c1cccc(=O)C)(cc1',
#  'cc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(=O)(=O)C)(C)CN((OC)C(NCS((N)(=O)(=O)(=O)(Cc2ccccc2C)(=O)(C)[C@@H]Sn1',
#  'S(CO)(C[nH](CO)NC(C)cc1',
#  '(Cc1ccc2c(=O)(N)CCO2',
#  'c1ccc(CO)(CC(=O)c2cccN(N)[nH](=O)(Cc2ccccc2C)(=O)(C)(C)(=O)CC(=O)NCc1ccc(CO)[C@@H](C)CNS[C@@H](C)c1',
#  'CCCCNC(N)(CO)O1',
#  '(F)(N)(c1)(=O)(=O)(C)(N)(c1)(=O)[C@H](=O)(C)(F)Ncc2)CNNCC1=CCCN=C1)(c1ccccc1)N(Cc1ccccc1Br)(=O)(=O)(CC(CC(CCCc1cS(C)(=O)c1Oc1cc[C@@H]CCC(C)OCCO2',
#  '(=O)(CCl)(=O)c1cccCN(=O)(=O)cc1',
#  '(=O)Nccc3c2OC)(=O)(C)CNSCNcc1',
#  'NCCCCcc1',
#  'C)CCc1ccccc1Cc1ccccc1)(=O)(CCCCNCCN(=O)(=O)(CO)cc3)cc2)(=O)c1ccc2cCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)(CC(=O)(CCF)(CO)(=O)(N)cc1',
#  '(=O)(=O)Nccc3c2OC)(=O)(Sc1ccc2cCC(=O)c1cccc(=O)((=O)CCCCNCSN(N)(CO)(CC(=O)(=O)(C)Nccc3c2OC)(=O)(C)CN(cc1',
#  'CN(=O)CCCCNCCN(N)cc2)N(C#CC2CC2)c2cccN(N)[nH](=O)N1CCOCC1)N(N)C)(=O)(O=C(-c3ccccCOC(=O)c1ccccc1',
#  '(=O)(N)(CC(=O)(=O)NCCCCcc1',
#  'C)(C)CN(CCCCNCCN(N)cc2)(=O)(=O)[C@@H]N((CCcc1',
#  '(=O)NCCCCcc1',
#  '(=O)CCCCNCSCNC)CCCCNCCN(CCCCNCCN(N)(CO)cc1',
#  'CNC)(=O)(=O)[C@@H]CCc1ccccc1Cc1ccccc1)(=O)cc1)cc1',
#  '(=O)(CO)cc3)cc2)(=O)c1ccc2cCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)Cnccc1',
#  '(C#N)ocCc1ccccc1C[C@H](=O)(=O)(=O)(F)CN(C#N)(=O)NC(=O)(OC)(CO)(Cl)(C)[C@H](C)NCSc2ccccCC(SN(F)C(=O)(Cc2ccccc2C)(=O)(C)[C@@H](Cc1ccc2ccccc2c1)(=O)(C)(N)(c1)(=O)c1cccCNNCC1=CCCN=C1)(c1ccccc1)N(C#CC2CC2)c2ccc(CC1=Cc1cNCCCC(=O)(=O)c1ccncc1)NCCCCCOCNCCCCCNCc1ccc(=O)(=O)C)(CO1',
#  '(F)(N)(c1)(=O)((CC(=O)Nccc3c2OC)(=O)(CCc1ccccc1',
#  '(=O)(=O)(Sc1ccc2cCC(=O)[C@@H]CN(C[nH](CO)(C)(N)[C@H](C)(N)S[C@@H](C)cc1',
#  'c1ccccc1',
#  'Cc1Oc1ncCN(NC(C)(=O)(C(Sc1ccc2cCCCCCC(=O)[C@@H]CCN(C[nH](CO)(C)(N)[C@H](C)(N)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1ccc[C@H]S(=O)c1ccc(CO)(=O)(=O)CNS[C@@H](N)NCCCCNCCCCNCCCC(=O)(=O)(C)c1cccnc1)S[C@@H](CCl)(=O)c1ccc(=O)(=O)(=O)c1ccc(CO)(=O)CNS[C@@H](N)NCCCCCOC[C@H](C#N)(=O)NCCCCC(=O)(N)(=O)Sn1',
#  'S(CO)(C[C@H](=O)cc1',
#  'cc1',
#  'cc1',
#  'CCCCNC(c1ccccc1)SCNC)(=O)c1cccCCCCNCCN(N)(CO)cc3)cc2)(=O)c1ccc2cCCCCNCcc(=O)CC(N)CCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(=O)c1ccc(CO)CCcc1',
#  '[C@@H](=O)c2ccc(O)(c1ccccc1)Sn1',
#  'CCCCNCC1=NCC(N)(CO)(=O)CNC)cc1',
#  '(CCCCCNCC1=NCC(N)[C@@H]C(Br)NCc1ccccn1)(=O)(=O)(=O)c1ccc[C@H](cc1',
#  '(=O)CCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)CCCCCNC(=O)(=O)[C@@H]CCc1ccccc1C(C[nH](=O)(Cc2ccccc2C)(=O)(C)[C@@H](C)(CC(=O)c1ccccc1',
#  '(=O)C)(=O)(CO)c1ccccc1',
#  '(=O)(=O)(c1ccccc1)SCNC)cc1',
#  '(CCCCCNC(c1ccccc1)SCNC)cc1',
#  'CNC)(=O)c1cccCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)(N)(CO)(CCF)(=O)(=O)NCCCCcc1',
#  'C)(C)CN(C)(=O)(=O)c1ccccn1)NS(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H](=O)(N)NCCCCcc1',
#  '(C)CN(CCCCNCCN(N)NCCCCCN((=O)c1cccCCCCNC(CO)cc1',
#  '[C@@H](=O)[C@H]CC(=O)CNc1ccccc12',
#  'C)cc1',
#  'CN(C#N)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCCN(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)c2cccN(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)N[C@H]cc[C@@H]NC)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CCCCNC1)(C)N(N)(CO)Cc1ccc(=O)(CC(=O)(=O)NCCCCcc1',
#  'C)(C)CN(CCCCNCCCO2',
#  'c1ccc(CO)(=O)CC(=O)[C@@H]CSCOc1cc2ccN(C)c1ccc2cCOC(=O)(N)(c1)(=O)(N)OCCC2C)(=O)c1cccCN(=O)CNc1ccccc12',
#  'C)cc1',
#  'NCCCCcc1',
#  'CCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NC[C@@H]C)c1O)CC(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCl)(=O)c1ccc(CO)(CO1',
#  '(F)(N)(c1)(=O)CN(N)(c1)(=O)[C@H]OCO2)C(Br)C2)cc2)N(=O)(=O)CCcc1',
#  'NCCCCcc1',
#  '(CO)(Oc2ccccc2OCCn2ccc(C)(Oc2ccccc2OCCn2ccc(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2ccc(C)(Nc2cccNCCCC(=O)c1cccS(=O)C)(CCCCNCCCO2',
#  '(c1)(=O)N(CO)cc1',
#  '(=O)Nc1cccCc1ccnc2c1NCc2cccc2)C)CN(C#N)(=O)c1cccc2cccnc12)CC(=O)N(CO)(O)(c1ccccc1)Sn1',
#  'CCCCNC(c1ccccc1)SCNC)cc1',
#  '(CCCCCNC(c1ccccc1)SCNC)(=O)c1cccCCCCNCCCO2',
#  'c1cccCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NCC)c1ccc2cSC)c1O)CC(=O)N(CO)(C)(c1ccccc1)S(C)N[C@H](Cc1cccnc1)(Cc1ccccc1Br)C(=O)S(CCc1cc(=O)[C@@H](N)cc1',
#  'c1ccccc1',
#  'COCNNCCCCC[C@H](c1ccc[C@H][C@H](=O)CCCCNC(CO)cCcc1',
#  '(=O)(=O)(=O)CCc1cccCc1ccnc2c1NCcc1',
#  '(=O)(=O)(CO)cc3)cc2)CNC)(=O)N(F)CN(CCF)C(=O)(Cc2ccccc2C)(=O)[C@@H](Cc1cccc2ccccc12)CCCCNC(O)[C@@H](NC(=O)(=O)cc1',
#  'SC)(=O)(F)CNcc1',
#  'CNC)CC(=O)c1ccccc12',
#  'C)cc1',
#  'CNcc1',
#  'NCCCCCN(C#N)(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)NS(Cc1ccccc1Br)(CO)(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)N[C@H]NCCCCCcn1',
#  'c1ccccc1',
#  '(=O)(N)CNCc1ccc(NC(C)Cc1Oc1ncCN(C)C)nc(c1)S(=O)(=O)(Nc2ccc(Nc2ccc(Nc2cccN1CCOCC1',
#  '(Oc2cNNCNCCCCcc1',
#  'C)F)C(=O)c1ccc(NC(C)C(=O)(O)cc1',
#  'C)(C)CN(CCCCNCCN(N)(CO)cc1',
#  '(CO1',
#  '(F)(N)(c1)(=O)c1cccCNcc1',
#  '(=O)(=O)N(CC1=C2C=CC=CC2CC=C1)(=O)c1cccc2cccnc12)(CO)cC(=O)[C@H](=O)ccc12',
#  'NNC(NC(=O)(NCOCc1ccncc1)NS(C)NS(C)(c1ccccc1)[nH](Cc1ccccc1Br)(CO)(C)(=O)(C)cc1',
#  '(C)(=O)c2cccN(N)[nH](=O)((CC(=O)[C@@H]Nc1ccc=O)(=O)(CC(CC(=O)(CC(=O)(CCc1ccccc1',
#  '(=O)CCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NC[C@@H]C)c1O)CC(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCCCNCcc2S(C)CNC)CCCCNCC1=NCC(N)(CO)cc1',
#  '(C(Sc1ccc2cCCCC(=O)[C@@H]CN(C[nH](CO)(C)cc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1cc(N)(C)(CC[C@H](N)SNCCCCC1C=CC=CC1',
#  '(CCCCNCC(=O)(=O)[C@@H]Nc2=O)CN(CO)[C@H]cc[C@@H]NC)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CCCCNC1)(C)(N)(CO)Cc1ccc(=O)(=O)SCCO2)SC)CC(=O)CC(CO)CCcc1',
#  '(C(C(CN(=O)(CO)(O)(CCC(C)(N)CCO2',
#  '(O)(CCC(C)(N)(NSNCc1ccncc1)(Br)C2)(c1)NCCCC(=O)(=O)CCc1ccc[C@H](=O)(=O)(=O)(=O)O1',
#  '(F)N(F)CN(CCF)C(=O)Cc1ncccc1Cc1ccc2c(=O)[C@H](CO)cccc1C(CO)(Cc1ccccc1Cl)Cc1cccc1',
#  '(=O)c2cccN(N)[nH](=O)N1CCOCC1)N(N)[nH](=O)(C)(=O)(C)(=O)c1ccccc1',
#  '(=O)(N2CCC(=O)N1CCOCC1)(NCS[C@@H](C)(=O)(N2CCC(=O)N1CCOCC1)(NCS[C@@H](cc1',
#  'NCCCC(N)C)NCNCCCC(N)(CO)CN(C)(=O)(=O)SCCO2)S[C@@H]C)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CC(=O)CCCCNC1)(C)(N)(CO)Cc1ccc(c1)(CC(Cc1cccc2ccccc12)NS(CO)NC(=O)CNCcc2)(C(Cc1ccccc1Br)(N)(CO)c1ccccc1)(=O)(=O)(C)(N)(CO)Cc1ccc(=O)(=O)c1ccccc1',
#  'Cnccc1',
#  'SC)(Oc2ccccc2OCCn2cccCc1ccc(c1)SC)c1O)CC(=O)Nc1Br',
#  'c1ccccc12',
#  'C)CNcc1',
#  'NCCCCC1C=CC=CC1',
#  '(CCCCNCCN(=O)N(CO)(CO)[C@H](C#N)c1ccc2ccc1O',
#  '(=O)SCCCC(C)(SN(F)N(CO)(CO)(C)(N)[C@H]Sn1',
#  '(=O)(C)(F)CN(CC(Cc1cccc2ccccc12)CCCCNCcc2SCCCCNC(N)(=O)(=O)SCN(N)NCCCCcc1',
#  'CCCCNCC)(=O)C(Br)NCc1ccccn1)(=O)(=O)c1ccc[C@H]c1cccc(=O)C)(cc1',
#  '(C#N)c1ccc(NC(=O)(=O)CCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NC[C@@H]C)nccc1',
#  'C)c1O)CC(=O)N(CO)N(=O)c2ccccCC((CC(=O)(=O)N(F)C(=O)(Cc2ccccc2C)(=O)(C)[C@@H]CCC(C)(=O)cc2)CNF)C(=O)(=O)CCO2)(CO)cc1',
#  '(C(Sc1ccc2cCCCC(=O)[C@@H]Ccc1O',
#  'c1ccccc1)(=O)(=O)(=O)CCCCNCSCCO2)(CO)cc1',
#  '(C[nH]C(Br)NCc1ccccn1)(=O)(=O)(=O)CCN(C[nH](CO)(C)(N)(NSNCc1ccncc1)(Br)C2)(c1)NCCCC(=O)(=O)CCc1ccc[C@H](=O)(=O)CS(CO)[C@H](C#N)c1ccc2cCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNCSN(N)[nH](=O)Sn1',
#  'S(CO)(CCCcc1',
#  '(N)(c1ccccc1)SCNC)(=O)c1cccCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CCc2cccc(=O)[C@@H]CCCCNCCN[C@@H]N(CO)(C#N)c2cccCCCCNC(N)[nH](=O)(=O)N1CCOCC1)N(N)[nH](=O)c1cccc(=O)((CC(Cc1ccccc1Br)(=O)(C)[C@@H]Nc2=O)CN(CO)[C@H]OCO2)Ccc1',
#  'c1ccc(N(=O)N=C1)CN(C)c(CC1CCCCC1)N(N)(C)c1cccCCNc1ccC(=O)(=O)(N2CCC(=O)c1ccc2cS[C@@H](NCSCOc1cc2cc(O)c1ccc(N)CCO2',
#  'c1cccC)(Oc2ccccc2OCCn2cccCc1ccc(=O)(=O)[C@H](C)c1cccnc1)S(CO)(N)OCCC2C)(=O)(=O)c1cccCNc1cccCN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1',
#  '[C@@H](=O)(N2CCC(=O)N1CCOCC1)(NCS[C@@H](NC(C)(=O)(O)(=O)(=O)c1ccccc1',
#  'Cnccc1',
#  'SC)(N)(CC(=O)(=O)(=O)CS(CO)NCNCCCC(CO)(Cc1ccc2c(=O)CC(C)(c1ccccc1)S((=O)N(F)Nc1cc(=O)((=O)[C@@H]C)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CCCCNC(O)[C@@H]N(=O)CCCCNC1)(C)(N)(CO)Cc1ccc(=O)(=O)(CO)(C#N)(N)(CO)cc1)CNcc1',
#  '(=O)(=O)(CO)cc3)cc2)(=O)c1ccc2cCCCCNCcc(=O)CC(N)[C@@H]ccc12',
#  'CCC=C1)(=O)cc1',
#  'NCCCCcc1',
#  'c1cnccn1)(=O)CCCCNCC)C(Br)NCc1ccccn1)(=O)(=O)(=O)NC)CC(Br)NCc1ccccn1)(=O)c1ccc[C@H]c1cccc(=O)(=O)C)(cc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(CO)c1ccccc1',
#  '(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2ccc(C)(Nc2cccNCCCC(=O)(=O)(=O)(=O)(=O)(CO)(O)c1ccc(=O)CNSC)(=O)CN(cc1',
#  '[C@@H]N(CC1=C2C=CC=CC2CC=C1)(=O)(N2CCC(=O)N1CCOCC1)(NCS[C@@H](CCCCNCSN(CO)(CO)(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H][C@@H][C@H]c1cNC(=O)(CCCCCNC(=O)(C[nH](=O)(C)[C@H](C)Nc2ccCc1ncccc1Cc1ccc2cnc(c1)(=O)[C@H](Cc1cccnc1)(Cc1ccccc1Br)c1ccccc1',
#  '(=O)(=O)(=O)Nccc3c2OC)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  '(=O)CCCCNCCNC)(=O)c1cccCCCCNC(O)[C@@H](=O)[C@@H]Ccc2)(=O)[C@@H][C@H](CC[C@@H](=O)c1ccc2cCN(N)CCO2',
#  'c1ccccc12',
#  'C)cc1',
#  'CNcc1',
#  'CNC)(=O)c1cccCc1ccnc2c1NCcc1',
#  'NCCCCcc1',
#  'C)C)(C)CN(CCCCNCCN(N)(CO)cc1',
#  '(C(Sc1ccc2cCC(=O)[C@@H]CN(C[nH](CO)(C)c1ccc(N)(N)(=O)[C@@H](C)c1cccnc1)c2ccc(C)(Nc2cccNCCCC(=O)(=O)(=O)((=O)(=O)CCCCNCS[C@@H]N(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H][C@@H][C@H]c1cNC(=O)(CCCCCNC(=O)(CC(C)Nc2ccCc1ncccc1Cc1ccc2cnc(c1ccccc1)(CO)(C)((=O)N[C@H](Cc1cccnc1)(Cc1ccccc1Br)C(=O)S(CCc1cc(=O)[C@@H](N)cc1',
#  'c1ccccc1',
#  'COCNNCCCCC[C@H][C@H](CCl)(=O)c1ccc[C@H](=O)c1ccc(CO)[C@@H](=O)cc1',
#  '(=O)(=O)N(C)CN(C)(=O)[C@H]CCC(=O)c1cccCCCC(=O)S(CO)(CO)(C(CO)(Cl)(C)(N)[C@H](=O)c1cccc(=O)(C)(CCC(=O)(OC)(CO)(Cl)(C)NCSN(F)Cc1Oc1ncCN(S(C)(=O)((=O)CCCC(=O)cc2)[C@H](=O)(CC1=Cc1cNCCCC(=O)cc2)C)CN(C)(=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H](=O)[C@@H]C(CC[C@@H]SCOc1cc2ccN(C)c1ccc2cCOC(=O)(N)CCO2',
#  'c1ccc(CCNc1ccc(C#N)(Cc1ccccc1Br)(CO)(=O)(c1)SN(Cc1ccc2ccccc2c1)[C@H](CO)(N[C@H](N)CN[C@@H]n1',
#  '(=O)CNc1ccccc12',
#  'C)cc1',
#  'CN(C#N)(=O)[C@@H]ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N(=O)c1ccccn1)NS(C)c1ccc=O)(CO)[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1cccS(=O)c1ccc[C@H](CO)(=O)c1cccCNS[C@@H](N)NCCCCNCCCC(=O)[C@H]=O)c1cccC)c1ccc[C@@H](=O)(=O)c1ccncc1)(=O)(=O)(=O)NCCCCCOCN=O)c1ccccc1',
#  'NCCCCc1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCCN(=O)c1cccc2cccnc12)CC(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'CC(N)(CO)Cc1ccc(=O)(=O)(=O)(CO)Cc1ccc(c1)S(CO)(C(C(C#N)(C[C@H](=O)cc1',
#  '(=O)CCCCNC(c1ccccc1)SN(=O)(CCCN(CCc1cc(=O)[C@@H](N)cc1',
#  'c1ccccc1',
#  'COCNNCCCCC[C@H][C@H](c1ccc[C@H](=O)CCCCNCSN(C)CN(C)(=O)[C@H]CCC(=O)cc2)C)(=O)c1ccc[C@@H](=O)c1ccncc1)(=O)(CC1CCCCC1)SC(CCc1ccccc1O',
#  'c1ccccc1)SNCCCC(=O)(O)(CCC(C)cc1',
#  '(C)CCC=C1)(=O)(=O)(CO)(Cl)(C)(N)(c1)(=O)N(C)c1ccc2cSc2ccccCC(S(CC1=Cc1cNCCCC(=O)(C)Nc2=O)O1',
#  '(F)Ncc2)cc1)(C#N)ocCc1ccccc1Cc1ccccc1)(=O)cc1)cc1',
#  '(=O)(=O)c2cccNC)(=O)(Sc1ccc2cCC(=O)(NCOCCO2)cc1',
#  '(=O)N(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N[C@H]CN(CCN(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)S(C)(=O)CCCCNCC[C@H][C@H](CO)Cc1ccc(c1)S(CC1=Cc1cNCCCC(=O)C)C(C)cc1',
#  '(C(Sc1ccc2cCCCC(=O)[C@@H]CN(C[nH](CO)(C)(N)[C@H](C)(N)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1ccc[C@H]S(=O)c1ccc(CO)(=O)(=O)CNS[C@@H](N)NCCCCNCCCC(=O)(=O)[C@H]=O)c1cccC)c1ccc[C@@H](=O)c1ccncc1)(=O)c1ccncc1)(=O)(=O)c1Br',
#  '(C#N)(=O)(OC)(CO)[C@H](C)NCSc2ccccCC(CCl)(=O)cc2)[C@H](=O)CC(SN(F)C(=O)(Cc2ccccc2C)(=O)(C)cc1',
#  'S(CO)cc3)cc2)(=O)CCCCNCCN(CO)cc1',
#  '(C(Sc1ccc2cCCCC(=O)(=O)[C@@H]CN(C[nH](CO)(C)c1ccc(CC[C@@H](C)(N)S[C@@H](C)OCCO2',
#  '(=O)(c1ccccc1',
#  'C(=O)(=O)(Cc2ccccc2C)(=O)(C)C)(C)(Br)NCc1ccccn1)(=O)(=O)(=O)NC(=O)(=O)CC(=O)N(F)CNNCC1=CCCN=C1)(c1ccccc1)N(c1)(=O)N(Cc1ccccc1Br)(CO)NC[C@@H]N(CO)cc1)CN(CO)[C@H]OCO2)Ccc1',
#  '(Cc1ccccn1)NS(CO)(C)c1ccccc12',
#  'C)cc1',
#  'SCN(C#N)(=O)(N)(c1ccccc1)c1ccccc1)(=O)(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCCCNCC1=NCC(N)[C@H](Cc1ccccc1Br)C(=O)c1cccCCCCNCCCO2',
#  '(C#CC2CC2)c2cccCCCCNC(=O)C(C)((CC(Cc1ccccc1Br)(=O)CCO2)(CO)(=O)NC[C@@H]C)c1O)CC(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCCCNCC1=NCC(N)[C@H]ccc2cC[C@H](Cc1ccccc1Br)c1ccc(N)(=O)(CC1CCCCC1)SC(CCC(C)cc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1ccC1C=CC=CC1',
#  '(CCl)(=O)c1cccCCNc1cc(N)(C)(CC(=O)(=O)(=O)CNCcc2)SNCCCCcc1',
#  'CCCCNCC)(C(Cc1ccccc1Br)Cc1Oc1ncCN((c1ccccc1)NCCCC(CO)(=O)CC(C)(=O)((=O)cc2)[C@H]NCCCCcc1',
#  '(=O)(=O)CCCCNCC)C(=O)c1ccc[C@H](=O)[C@@H]C)CN(C#N)[C@@H](cc1',
#  'SCNcc1',
#  'NCCCCcc1',
#  'C)(=O)c1ccncc1)(=O)c1Br',
#  '(C#N)(=O)c1ccncc1)NCCCCcc1',
#  '(C#N)(=O)(OC)(CO)NCCCCCNC(Cc1ccccc1Cl)Cc1cccc1',
#  '(=O)(N)(c1ccccc1)c1ccccc1)(=O)c2cccCCCCNCSN(CO)(C)N(N)C)(=O)c1cccc(=O)(cc1',
#  '(=O)N(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(N)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)N[C@H]c1ccccc1',
#  '(=O)(N)CNCc1ccc(NC(C)Cc1Oc1ncCN(C)C)nc(c1)S(=O)(Nc2cccN1CCOCC1',
#  '(Oc2cN[C@H](Nc2cccN[C@H](Nc2cccNCCCCNC(C#N)[C@@H](=O)[C@@H][C@H](=O)(=O)(F)CN(CCF)C(=O)(=O)c2=O)(=O)[C@H](C)(=O)c1ccccn1)NS(C)c1cccCc1ccc(CO)(N)(CO)(C)(N)(CO)Cc1ccc(=O)Cc1ncccc1CNC(=O)(=O)CC(CO)O',
#  '(N)(=O)N=O)(=O)(CC(=O)(Sc1ccc2cCC(=O)(=O)nccc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(=O)c1cccc(=O)((=O)N(CO)(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '(=O)(N)Cnccc1',
#  '(C(C(Sc1ccc2cCC(C)CNc1cccc(=O)[C@@H](CCl)(=O)(=O)CCCCNCCN(C[nH](CO)(C)(N)(CCC(C)(N)[C@H](C)(N)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1cccCC(Cc1ccccc1Br)(CO)(=O)(C)(N)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1ccc[C@H](=O)CNS(CC1=CCc1ccnc2c1NCcc1',
#  '(CO)cC(Br)C2)(c1)SC)CNcc1',
#  'NCc1ccccn1)(=O)(=O)c1ccccc12',
#  'C)cc1',
#  'CNNCc1ccccn1)(=O)(=O)c2cccN(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H](C)c1O)CCcc1',
#  'NCCCCcc1',
#  'c1cnccn1)(=O)NCCCCNCC)(N)(CC(=O)(=O)(=O)(Cc1cccnc1)(Cc1ccccc1Br)C(=O)S(CCc1cc(=O)(CO)(C[nH](CO)(C)[C@@H](C)(N)cc1',
#  '(C)cc3)cc2)(=O)c1ccc2cCCCCNCcc(=O)CC((=O)N[C@H](=O)(CO1',
#  '(F)CN(CC(=O)(C)cc1',
#  '(=O)c2cccN(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)N(CO)(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'COc1cc2cc(O)c1ccccc1)N[C@H]c1ccccc1',
#  '(=O)(N)CNCc1ccc(NC(C)Cc1Oc1ncCN(C)C)nc(c1)S(=O)(=O)(=O)(Nc2ccc(Nc2ccc(Nc2cccNCCCC(=O)[C@@H](C)CN(CCCCNCCN(N)(=O)CC(=O)CCCC(=O)[C@@H]CCc1ccc(c1)Scc2)cc1)(Cc1cccc2ccccc12)NS(CO)Cc1ccc(CO)(N)(CO)Cc1ccccc1O',
#  'c1ccccc1)(=O)(C)(N)(CO)Cc1ccc(CO)Cc1ccc(=O)(=O)SCCO2)SC)CC(=O)CCC(CO)CCcc1',
#  '(CCCcc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1cc(N)(C)(CC[C@H](N)SNCCCCC1C=CC=CC1',
#  '(CCCCNCC(=O)(=O)[C@@H]Nc2=O)CN(CO)[C@H]cc[C@@H]NC)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CCCCNC1)(C)(N)(CO)Cc1ccc(=O)(=O)CCO2)SC)CC(=O)CCC(CO)CCcc1',
#  '(C(CN(=O)(CO)(O)(CCC(C)(N)(NSNCc1ccncc1)(Br)C2)(c1)NCCCC(=O)(=O)CC(=O)(=O)CCcc1',
#  'C)CCc1ccccc1Cc1ccccc1)(=O)cc1)cc1',
#  '(=O)(CO)c(CC1CCCCC1)N(C)(=O)((CCNCCCC(CO)(=O)(C)(=O)CC(C)[C@@H]C)c1O)CC(=O)N(CO)(C)(c1ccccc1)Sn1',
#  'CCCCNCC1=NCC(N)[C@H]OCO2)Ccc1',
#  '(C)CNC)cc1',
#  '(C)CN(C#N)(=O)(N)(c1ccccc1)c1ccccc1)cc1',
#  'NCCCCN(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NNC(NCOCc1ccncc1)NNC(NCOCc1ccncc1)NS(C)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)[C@H](Cc1cccnc1)(Cc1ccccc1Br)(N)cc1',
#  'SNCCCCN(=O)c1cccc2cccnc12)CC(=O)ccc12',
#  'NS(NCOCc1ccncc1)NS(C)N(OC)(Cc1ccccc1Cl)(O)[C@@H](NC(=O)c1ccc2c(=O)(=O)(N)(N)(c1ccccc1)c1ccc(=O)N(=O)N1CCOCC1',
#  'c1cc(=O)[C@@H]C=CC(C#N)ocCc1ccccc1C[C@H](=O)(C(N)cc1',
#  '(CO)cC)(Oc2ccccc2OCCn2cccCc1ccccc1O',
#  'c1ccccc1)(=O)CCCCNCCcc1',
#  '(C(Sc1ccc2cCC(=O)[C@@H]CNC(=O)CCCCNCc1cccCCNc1cc(N)(CO)cCCc1ccccc2)cc1)[C@H](=O)[C@@H](=O)[C@@H](N)(C(C#N)c1ccc2cnc(c1ccccc1)SN[C@H](Cc1cccnc1)(Cc1ccccc1Br)C(N)(CC(=O)(=O)Sn1',
#  'S(CO)(C[C@H]cc1',
#  'cc1',
#  'cc1',
#  'CCCCNC(c1ccccc1)SCNC)cc1',
#  'CCCCNC(c1ccccc1)SCNC)(=O)CN(N)(CO)cc1',
#  '(C(Sc1ccc2cCCCC(=O)[C@@H]CN(C[nH](CO)(C)(N)[C@H](C)(N)SNCCCCC1C=CC=CC1',
#  '(CCCCNCC(=O)(=O)[C@H](Cc1cccnc1)(Cc1ccccc1Br)CNS(CO)NC(CO)(Cc1ccc2cS[C@H]c1ccc(CO)(O)(CCC(C)(N)(NSNCc1ccncc1)(Br)C2)(c1)NCCCC(=O)(=O)CCc1ccc[C@H](=O)(=O)(=O)(=O)CS(CO)[C@H](C#N)c1ccc2ccc1O',
#  '(=O)(CC(=O)(C)[C@@H]CCCCNCSCC(Cc1ccccc1Br)[C@H](N)(c1)(=O)(=O)(C)(F)Ncc2)CNNCC1=CCCN=C1)(c1ccccc1)N(Cc1ccccc1Br)(=O)(=O)(CC(CC(CC(CCF)C(=O)(=O)(=O)(=O)NCCCCcc1',
#  'C)(C)CN(CCCCNCN(=O)(CCcc2)Nc2ccCc1ncccc1Cc1ccc2cnc(c1ccccc1)(CO)(C)((=O)CC(=O)N[C@H](Cc1cccnc1)(Cc1ccccc1Br)C(N)(C[nH](=O)S[C@@H](C)(CC(Cc1cccc2ccccc12)NSn1',
#  'CCCCNCC1=NCC(N)C)(N)[C@H](=O)(=O)c1cccCN(C)(CCcc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)NCCCCNCCCC(=O)c1ccncc1)(=O)(=O)(=O)(CO)(Cl)(C)[C@H](C)[C@H](C)NCSc2ccccCC(Sn1',
#  'S(CO)(O)(C[C@H]c1ccccc1',
#  'Cnccc1',
#  '(C)c(CC1CCCCC1)N(C)c1cccCCNc1cc(N)(C)(CC[C@H](N)SNCCCCC1C=CC=CC1',
#  '(CCCCNCC(=O)(=O)[C@@H]N(N)CCO2',
#  '(C#CC2CC2)c2cccCCCCNCc1ccc(NC(=O)N1CCOCC1',
#  '(Oc2cN[C@H](Nc2ccc(Nc2cccN(O)c1ccccc1)(=O)[C@@H](C)c1',
#  '(=O)CCCCNCSCCO2)(CO)c1cccnc1N2C1CC1',
#  '(Cc2ccccc2Br)cn1',
#  'c1ccccc1',
#  '[C@@H][C@@H][C@H]c1cNC(=O)cc1',
#  'c1cnccn1)(=O)ccc12',
#  'NNCCCCCNC(C#N)cc1)cc1',
#  'NCCCCcc1',
#  '(=O)CCCCNC(=O)C(Br)NCc1ccccn1)(=O)c1ccc[C@H](=O)C)(c1cccCC(=O)(=O)c2cccc2)C)CNcc1',
#  'S(OC)CN(=O)((c1ccccc1)NCCCC(CO)(C)(=O)((=O)(C)(=O)CC(=O)cc2)[C@H](=O)(=O)NC(C)(Cc1ccc2c(=O)CCc12)(Cc1ccccc1Br)N1CCOCC1)NCc1ccc(CO)cccc1C(CO)(Cc1ccccc1Cl)Cc1cccc1',
#  '(=O)c2cccN(N)[nH](=O)N1CCOCC1)N(N)[nH](=O)(O=C(-c3ccccCOC[C@H](=O)c1ccccn1)NS(C)c1cccCc1ccc(CO)(N)(CO)c1ccc(CCC(N)(C(C#N)(C(=O)(=O)Cc1ncccc1CNC(=O)c1ccccc1',
#  'c1cccnc1)[C@H](N)NC(=O)(=O)NCOCCO2)(c1ccccc1)(Cc1ccccc1Br)NC[C@@H](NCSn1',
#  'CCCCNCC1=NCC(N)(c1ccccc1)c1ccc(NCc1ccc(NC(C)C)Cc1Oc1ncCNcc1',
#  '(CO)c(CC1CCCCC1)N(C)C(C)c1cccCCNc1cc(=O)cc1)(C)(CC[C@@H]S(CO)[C@@H](C)[C@H](N)OCCC2C)(=O)c1cccCN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1',
#  '[C@@H](=O)(N2CCC(=O)N1CCOCC1)(NC(=O)N1CCOCC1)(NCS[C@@H](NC(C)(=O)(O)(=O)(=O)(=O)c1ccccc1',
#  'CF)C)(N)(CC(=O)[C@H](=O)(=O)NCCCCcc1',
#  'C)(C)CN(CCCCNCCN(N)(CO)cc1',
#  '(C(Sc1ccc2cCCCCCC(=O)[C@@H]CN(C[nH](CO)(C)(N)[C@H](C)(N)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1ccc[C@H]S(=O)c1ccc(CO)(=O)CNS[C@@H](N)NCCCCNCCCCNCCCC(=O)[C@H]=O)c1cccC)c1ccc[C@@H](=O)(=O)[C@H]c1cccc(=O)c1ccncc1)(=O)c1ccc(CO)[C@@H](CO1',
#  '(F)(N)OCCC2C)(=O)c1ccc(CO)cccc1C(CO)(C)(N)(N)(c1)S[C@@H](C)OCCO2',
#  '(=O)(CCl)(=O)c1cccCN(N)(CCc1ccc(=O)c1cccC)(CO)CN(CO1',
#  '(F)(N)cc2)(CO)[C@@H](C)(N)OCCC2C)(=O)c1cccCN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)(=O)(C1=CC=CCC1)(=O)c1ccc(CO)[C@@H](=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H](=O)[C@@H](N)NCCCC[C@@H](C)c1',
#  '(=O)[C@@H]n1',
#  'SCOc1cc2ccN(C)c1ccc2cCOC(=O)(N)(c1ccccc1)c1ccc=O)(CO)(CCN(=O)CNS(C)(=O)N1CCOCC1',
#  'COc1cc2ccNNCCCCC[C@H][C@H][C@H](CCl)(=O)c1cccCCCCNC(CO)[C@H](C)[C@H](=O)CN(CCF)C(=O)(=O)CNCcc2)(=O)(C(Cc1ccccc1Br)(N)(=O)(O)c1ccc(=O)[C@H](C)[C@H](=O)CCCCNC(O)[C@@H]N(CO)(N)CNNCC1=CCCN=C1)(c1ccccc1)Ncc1',
#  '(=O)(=O)(CC(=O)N[C@H](Cc1cccnc1)(Cc1ccccc1Br)C(=O)S(CCc1cc(=O)[C@@H](C#N)[C@@H](N)cc1',
#  'c1ccccc1',
#  'COCNNCCCCC[C@H]((C)CN((=O)c1ccc[C@H](=O)CCCCNC(CO)[C@H](=O)cc1',
#  '[C@@H](=O)NNCCCCC[C@H](C)CN(C)(=O)[C@H]CCC(=O)c2=O)(=O)c1ccc(CO)(CO)[C@H](CO)[C@@H](C)(N)cc2)CN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)c1cccc(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1',
#  '(=O)N1CCOCC1)CCCCNCcc(=O)(=O)[C@@H]Cnccc1',
#  '(C#N)c1cccC)cc1',
#  '(C#N)c1cccCc1ccnc2c1NCcc1',
#  '(CO)c1ccccc1',
#  '(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2cccCCCCNC(=O)(=O)c1ccc(=O)(=O)C)(=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H]']

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole


mols = [Chem.MolFromSmiles(smi) for smi in new if Chem.MolFromSmiles(smi) is not None]
Draw.MolsToGridImage(mols, molsPerRow=5, subImgSize=(200, 200), legends=[str(i) for i in range(len(mols))])
# Out:
# [20:42:39] SMILES Parse Error: syntax error while parsing: (cc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(cc1' for input: '(cc1'
# [20:42:39] SMILES Parse Error: unclosed ring for input: 'NCCCCcc1'
# [20:42:39] SMILES Parse Error: extra close parentheses while parsing: C)(C)CN(C)(=O)[C@H]OCO2)CCCc1ccc(c1)(CC(Cc1cccc2ccccc12)NS(Cc1ccccc1Br)(CO)NC(CO)[C@@H][C@@H](Cc1ccc2cS[C@H]c1cccCCO2)oc(=O)c2ccc(O)CC(C#N)cc1)(C#N)ocCc1ccccc1C[C@H](=O)c2cccc2)C)CNcc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES 'C)(C)CN(C)(=O)[C@H]OCO2)CCCc1ccc(c1)(CC(Cc1cccc2ccccc12)NS(Cc1ccccc1Br)(CO)NC(CO)[C@@H][C@@H](Cc1ccc2cS[C@H]c1cccCCO2)oc(=O)c2ccc(O)CC(C#N)cc1)(C#N)ocCc1ccccc1C[C@H](=O)c2cccc2)C)CNcc1' for input: 'C)(C)CN(C)(=O)[C@H]OCO2)CCCc1ccc(c1)(CC(Cc1cccc2ccccc12)NS(Cc1ccccc1Br)(CO)NC(CO)[C@@H][C@@H](Cc1ccc2cS[C@H]c1cccCCO2)oc(=O)c2ccc(O)CC(C#N)cc1)(C#N)ocCc1ccccc1C[C@H](=O)c2cccc2)C)CNcc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing
1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: COCNNCCCCC[C@H]((C)CN((=O)c1ccc[C@H](=O)CCCCNC(CO)[C@H](=O)cc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES 'COCNNCCCCC[C@H]((C)CN((=O)c1ccc[C@H](=O)CCCCNC(CO)[C@H](=O)cc1' for input: 'COCNNCCCCC[C@H]((C)CN((=O)c1ccc[C@H](=O)CCCCNC(CO)[C@H](=O)cc1'
# [20:42:39] SMILES Parse Error: extra close parentheses while parsing: [C@@H](=O)NNCCCCC[C@H](C)CN(C)(=O)[C@H]CCC(=O)c2=O)(=O)c1ccc(CO)(CO)[C@H](CO)[C@@H](C)(N)cc2)CN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)c1cccc(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '[C@@H](=O)NNCCCCC[C@H](C)CN(C)(=O)[C@H]CCC(=O)c2=O)(=O)c1ccc(CO)(CO)[C@H](CO)[C@@H](C)(N)cc2)CN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)c1cccc(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1' for input: '[C@@H](=O)NNCCCCC[C@H](C)CN(C)(=O)[C@H]CCC(=O)c2=O)(=O)c1ccc(CO)(CO)[C@H](CO)[C@@H](C)(N)cc2)CN(N)cc2)N(CC1=C2C=CC=CC2CC=C1)(=O)(=O)c1cccc(=O)(C1=CC=CCC1)(=O)c1ccc(CO)cCcc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: (=O)N1CCOCC1)CCCCNCcc(=O)(=O)[C@@H]Cnccc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(=O)N1CCOCC1)CCCCNCcc(=O)(=O)[C@@H]Cnccc1' for input: '(=O)N1CCOCC1)CCCCNCcc(=O)(=O)[C@@H]Cnccc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: (C#N)c1cccC)cc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(C#N)c1cccC)cc1' for input: '(C#N)c1cccC)cc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: (C#N)c1cccCc1ccnc2c1NCcc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(C#N)c1cccCc1ccnc2c1NCcc1' for input: '(C#N)c1cccCc1ccnc2c1NCcc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: (CO)c1ccccc1
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(CO)c1ccccc1' for input: '(CO)c1ccccc1'
# [20:42:39] SMILES Parse Error: syntax error while parsing: (C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2cccCCCCNC(=O)(=O)c1ccc(=O)(=O)C)(=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H]
# [20:42:39] SMILES Parse Error: Failed parsing SMILES '(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2cccCCCCNC(=O)(=O)c1ccc(=O)(=O)C)(=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H]' for input: '(C)(Oc2ccccc2OCCn2ccc(C)c1cccnc1)c2cccCCCCNC(=O)(=O)c1ccc(=O)(=O)C)(=O)cc3ccCCCCNC[C@@H]Ccc2)cc1)[C@H]'

# %%
model_state_path = "overfit_Only3_BPS.pkl"
torch.save(model.state_dict(), model_state_path)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
model_state_path = "Only3_BPS.pkl"
torch.save(model.state_dict(), model_state_path)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %% [markdown]
# # Analysis of the result
#
# This is the initial. Gneeral one with the full pipeline.
# I will do further analysis on this set.

# %%
# Calculate the valid smiles

from rdkit import Chem
from rdkit.Chem import Draw
import pandas as pd

# Example dataset loading
# protease_df and nrti_df should already be loaded as shown in your initial step

# Function to check for valid RDKit Mol objects and catch potential syntax errors
def is_valid_for_drawing(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:  # Check if RDKit failed to create a Mol object
            return False
        Chem.SanitizeMol(mol)  # Attempt to sanitize the molecule, catching syntax errors
        return True
    except:  # Catch any exceptions thrown by RDKit (e.g., sanitization errors)
        return False
    
def get_valid_mols(smiles_list):
    valid_mols = []
    for smiles in smiles_list:
        if is_valid_for_drawing(smiles):
            valid_mols.append(smiles)
    return valid_mols


valid_smiles = get_valid_mols(new)
print(f"Number of valid smiles: {len(valid_smiles)}")
#as percentage
print(f"Percentage of valid smiles: {len(valid_smiles)/len(new)*100:.2f}%")
# Out:
# Number of valid smiles: 24
# Percentage of valid smiles: 9.76%
# [20:26:07] SMILES Parse Error: syntax error while parsing: (CCc1ccccn1)S(=O)(=O)c1ccc(N)cc1
# [20:26:07] SMILES Parse Error: Failed parsing SMILES '(CCc1ccccn1)S(=O)(=O)c1ccc(N)cc1' for input: '(CCc1ccccn1)S(=O)(=O)c1ccc(N)cc1'
# [20:26:07] SMILES Parse Error: extra close parentheses while parsing: O=C(O)c2cccc(c1ccccc1)c1ccccc1)S(=O)(=O)c1c(=O)COC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)NCCCC[C@@H](CO)N(CC(C)C)S(=O)(=O)c1cccc2cccnc12)C(c1ccccc1)c1ccccc1
# [20:26:07] SMILES Parse Error: Failed parsing SMILES 'O=C(O)c2cccc(c1ccccc1)c1ccccc1)S(=O)(=O)c1c(=O)COC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)NCCCC[C@@H](CO)N(CC(C)C)S(=O)(=O)c1cccc2cccnc12)C(c1ccccc1)c1ccccc1' for input: 'O=C(O)c2cccc(c1ccccc1)c1ccccc1)S(=O)(=O)c1c(=O)COC(=O)N[C@H](C(=O)NCCCCC(C(N)=O)NCCCC[C@@H](CO)N(CC(C)C)S(=O)(=O)c1cccc2cccnc12)C(c1ccccc1)c1ccccc1'
# [20:26:07] SMILES Parse Error: extra open parentheses for input: 'COC(=O)(=O)N[C@H](C(=O)c1ccccc1'
# [20:26:07] SMILES Parse Error: extra open parentheses for input: 'CC(C)CN([C@H]CNS(=O)[C@H](C(Cc1ccccc1Br)(c1)C1=NCC(=O)(=O)NCCCCC(C(=O)(=O)(Cc2ccccc2C)COCO2)S(=O)c1cccs1)C(=O)c1ccc2c(c1)CCO2'
# [20:26:07] SMILES Parse Error: unclosed ring for input: 'ccc12'
# [20:26:07] SMILES Parse Error: unclosed ring for input: 'C(=O)N[C@@H](Cc1ccccc1Br)Cc1ccc2c(c1)S(=O)(=O)(=O)(=O)(CO)N[C@@H](Cc1cccc2ccccc12)(c1)CCO2'
# [20:26:07] SMILES Parse Error: extra open parentheses for input: 'C(=O)(O)cccc1C(=O)NCCCC[C@@H](NC(=O)N[C@H](CO)N(CC(C)C)S(=O)(=O)(=O)c1ccc(N)cc1'
# [20:26:07] SMILES Parse Error: extra close parentheses while parsing: CC(C)(Sc1ccc2c(F)F)c3)c12)C(=O)NCCCCC(C(=O)NNCCCCC(C(N)cc2)cn1
# [20:26:07] SMILES Parse Error: Failed parsing SMILES 'CC(C)(Sc1ccc2c(F)F)c3)c12)C(=O)NCCCCC(C(=O)NNCCCCC(C(N)cc2)cn1' for input: 'CC(C)(Sc1ccc2c(F)F)c3)c12)C(=O)NCCCCC(C(=O)NNCCCCC(C(N)cc2)cn1'
# [20:26:07] SMILES Parse Error: extra close parentheses while parsing: COC(=O)NCCCC[C@@H](CO)N[C@@H]O=C1Nc2cccN(CC(C)F)c3)c12)C(=O)NCCCC[C@@H](CO)N(CC(C)C)S(=O)(=O)c1ccc2cN(Cc1cccnc1)S(=O)(=O)c1ccc(N)cc1
# [20:26:07] SMILES Parse Error: Failed parsing SMILES 
'
# [20:26:07] SMILES Parse Error: extra open parentheses for input: 'CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](NS(=O)[C@@H](Cc1ccccc1Br)NC(=O)NCc1ccncc1)C(=O)NCCCC[C@@H](=O)O'
# [20:26:07] SMILES Parse Error: unclosed ring for input: 'Cc1ccccc1C[C@H](CO)N(CC(C)C)S(=O)(=O)oc(O)cccc1C(=O)N1CCOCC1'
# [20:26:07] SMILES Parse Error: extra open parentheses for input: 'CC(C)CN([C@H](CO)CCCCNC(=O)[C@@H](Cc1ccccc1Cl)NC(=O)c1ccc2c(c1)C1=NCC(C)(CC1CCCCC1)(CC1=C2C=CC=CC2CC=C1)NC(=O)N[C@@H]c1c(=O)cn1'
# [20:26:07] SMILES Parse Error: syntax error while parsing: (-c3cccc(c1)OCO2)S(=O)(=O)c1ccc(N)S(=O)c1ccc(N)cc1
# [20:26:07] SMILES Parse Error: Failed parsing SMILES '(-c3cccc(c1)OCO2)S(=O)(=O)c1ccc(N)S(=O)c1ccc(N)cc1' for input: '(-c3cccc(c1)OCO2)S(=O)(=O)c1ccc(N)S(=O)c1ccc(N)cc1'

# %%
protease_full = pd.read_csv('C:\\Users\\Rebe\\Documents\\Python programms\\Capstone_code\\Data\\hiv_protease_inhibitors_data_chemlb.csv')
protease = protease_full['canonical_smiles']
print(protease.shape)

nrti_full = pd.read_csv('C:\\Users\\Rebe\\Documents\\Python programms\\Capstone_code\\Data\\nrtis_hiv_chemlb_full.csv')
nrti = nrti_full['canonical_smiles']
print(nrti.shape)
# Out:
# (43,)
# (9,)

# %%
#make the same one for the original dataset
#create a function for code reusability
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Crippen
from rdkit.Chem.Draw import MolsToGridImage
import matplotlib.pyplot as plt
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Crippen
from rdkit.Chem.Draw import MolsToGridImage
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem, RDLogger
from rdkit.Chem import BondType, AllChem, Descriptors, Descriptors3D, Draw, Lipinski, rdMolDescriptors
from rdkit.Chem.Draw import MolsToGridImage
#import DataStructs
from rdkit.Chem import AllChem, DataStructs

def get_properties(molecules):
    # Calculate properties
    properties = []
    for mol in molecules:
        mw = Descriptors.MolWt(mol)
        logp = Crippen.MolLogP(mol)
        hbd = rdMolDescriptors.CalcNumHBD(mol)
        hba = rdMolDescriptors.CalcNumHBA(mol)
        psa = rdMolDescriptors.CalcTPSA(mol)
        ro5_violations = rdMolDescriptors.CalcNumLipinskiHBA(mol) + rdMolDescriptors.CalcNumLipinskiHBD(mol)
        cx_logd = rdMolDescriptors.CalcCrippenDescriptors(mol)[1]
        mw_freebase = Descriptors.ExactMolWt(mol)
        full_mwt = Descriptors.HeavyAtomMolWt(mol)
        num_h_acceptors = rdMolDescriptors.CalcNumHBA(mol)
        num_h_donors = rdMolDescriptors.CalcNumHBD(mol)

        properties.append([mw, logp, hbd, hba, psa, ro5_violations, cx_logd, mw_freebase, full_mwt, num_h_acceptors, num_h_donors])

    # Convert to DataFrame for easier plotting
    df = pd.DataFrame(properties, columns=['MW', 'LogP', 'HBD', 'HBA', 'PSA', 'NumRo5Violations', 'CxLogD', 'MwFreebase', 'FullMwt', 'NumHAcceptors', 'NumHDonors'])

    # Plotting
    fig, ax = plt.subplots(1, 1, figsize=(12, 6))
    df.hist(ax=ax, color = 'purple')
    plt.title('BPS full pipeline properties distribution')
    plt.tight_layout()
    plt.show()
    return df

# %%
df_protease = get_properties([Chem.MolFromSmiles(smi) for smi in protease if Chem.MolFromSmiles(smi) is not None])
df_nrti = get_properties([Chem.MolFromSmiles(smi) for smi in nrti if Chem.MolFromSmiles(smi) is not None])
df = get_properties([Chem.MolFromSmiles(smi) for smi in valid_smiles if Chem.MolFromSmiles(smi) is not None])
# Out:
# C:\Users\Rebe\AppData\Local\Temp\ipykernel_14060\1062921395.py:43: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax, color = 'purple')
# C:\Users\Rebe\AppData\Local\Temp\ipykernel_14060\1062921395.py:43: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax, color = 'purple')
# C:\Users\Rebe\AppData\Local\Temp\ipykernel_14060\1062921395.py:43: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax, color = 'purple')

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from numpy.random import seed

def compare_molecular_properties(descriptor, df_generated, df_protease, df_nrti):
    """
    Perform Mann-Whitney U tests to compare a molecular descriptor between generated molecules
    and both protease inhibitors and NRTIs.

    Parameters:
    - descriptor: The molecular descriptor to compare.
    - df_generated: DataFrame containing descriptors for generated molecules.
    - df_protease: DataFrame containing descriptors for protease inhibitors.
    - df_nrti: DataFrame containing descriptors for NRTIs.

    Returns:
    - A DataFrame with the test results.
    """
    # Seed the random number generator for reproducibility
    seed(3)
    
    # Extract descriptor values for each group
    generated_values = df_generated[descriptor].dropna()
    protease_values = df_protease[descriptor].dropna()
    nrti_values = df_nrti[descriptor].dropna()

    # Compare generated molecules with protease inhibitors
    stat_protease, p_protease = mannwhitneyu(generated_values, protease_values, alternative='two-sided')

    # Compare generated molecules with NRTIs
    stat_nrti, p_nrti = mannwhitneyu(generated_values, nrti_values, alternative='two-sided')

    # Interpret results
    alpha = 0.05
    interpretation_protease = 'Different distribution (reject H0)' if p_protease <= alpha else 'Same distribution (fail to reject H0)'
    interpretation_nrti = 'Different distribution (reject H0)' if p_nrti <= alpha else 'Same distribution (fail to reject H0)'

    # Compile results into a DataFrame
    results_df = pd.DataFrame({
        'Descriptor': [descriptor, descriptor],
        'Comparison': ['Generated vs. Protease', 'Generated vs. NRTI'],
        'Statistics': [stat_protease, stat_nrti],
        'P-Value': [p_protease, p_nrti],
        'Interpretation': [interpretation_protease, interpretation_nrti]
    })

    return results_df

def all_mannwhitney(df_generated, df_protease, df_nrti, descriptors):
    """
    Compare all specified descriptors between generated molecules, protease inhibitors, and NRTIs.

    Parameters:
    - df_generated: DataFrame with generated molecules' properties.
    - df_protease: DataFrame with protease inhibitors' properties.
    - df_nrti: DataFrame with NRTIs' properties.
    - descriptors: List of descriptors to compare.

    Returns:
    - A DataFrame aggregating all comparison results.
    """
    all_results = pd.DataFrame()
    for descriptor in descriptors:
        results = compare_molecular_properties(descriptor, df_generated, df_protease, df_nrti)
        all_results = pd.concat([all_results, results], ignore_index=True)
    
    return all_results

# Example usage
# Assuming df_generated, df_protease, and df_nrti are your DataFrames containing the molecular properties
descriptors = ['MW', 'LogP', 'HBD', 'HBA', 'PSA', 'NumRo5Violations', 'CxLogD', 'MwFreebase', 'FullMwt', 'NumHAcceptors', 'NumHDonors']
comparison_results = all_mannwhitney(df, df_protease, df_nrti, descriptors)

comparison_results
# Out:
#           Descriptor              Comparison  Statistics       P-Value  \
# 0                 MW  Generated vs. Protease       191.0  2.197301e-05
# 1                 MW      Generated vs. NRTI        84.0  3.420665e-01
# 2               LogP  Generated vs. Protease       358.0  3.941200e-02
# 3               LogP      Generated vs. NRTI        68.0  1.102449e-01
# 4                HBD  Generated vs. Protease       132.5  1.261230e-07
# 5                HBD      Generated vs. NRTI       119.0  6.622265e-01
# 6                HBA  Generated vs. Protease       213.0  2.713960e-05
# 7                HBA      Generated vs. NRTI        56.0  3.554796e-02
# 8                PSA  Generated vs. Protease       150.5  1.752199e-06
# 9                PSA      Generated vs. NRTI        90.0  4.788795e-01
# 10  NumRo5Violations  Generated vs. Protease       145.0  9.551578e-07
# 11  NumRo5Violations      Generated vs. NRTI        96.0  6.405483e-01
# 12            CxLogD  Generated vs. Protease       186.0  1.637941e-05
# 13            CxLogD      Generated vs. NRTI        86.0  3.846809e-01
# 14        MwFreebase  Generated vs. Protease       191.0  2.195642e-05
# 15        MwFreebase      Generated vs. NRTI        84.0  3.420262e-01
# 16           FullMwt  Generated vs. Protease       191.0  2.196471e-05
# 17           FullMwt      Generated vs. NRTI        82.0  3.025649e-01
# 18     NumHAcceptors  Generated vs. Protease       213.0  2.713960e-05
# 19     NumHAcceptors      Generated vs. NRTI        56.0  3.554796e-02
# 20        NumHDonors  Generated vs. Protease       132.5  1.261230e-07
# 21        NumHDonors      Generated vs. NRTI       119.0  6.622265e-01
#
#                            Interpretation
# 0      Different distribution (reject H0)
# 1   Same distribution (fail to reject H0)
# 2      Different distribution (reject H0)
# 3   Same distribution (fail to reject H0)
# 4      Different distribution (reject H0)
# 5   Same distribution (fail to reject H0)
# 6      Different distribution (reject H0)
# 7      Different distribution (reject H0)
# 8      Different distribution (reject H0)
# 9   Same distribution (fail to reject H0)
# 10     Different distribution (reject H0)
# 11  Same distribution (fail to reject H0)
# 12     Different distribution (reject H0)
# 13  Same distribution (fail to reject H0)
# 14     Different distribution (reject H0)
# 15  Same distribution (fail to reject H0)
# 16     Different distribution (reject H0)
# 17  Same distribution (fail to reject H0)
# 18     Different distribution (reject H0)
# 19     Different distribution (reject H0)
# 20     Different distribution (reject H0)
# 21  Same distribution (fail to reject H0)

# %%
#count the ones with same distribution
same_distribution = comparison_results[comparison_results['Interpretation'] == 'Same distribution (fail to reject H0)']
len(same_distribution)/len(comparison_results)*100
# Out:
# 40.909090909090914

# %%
def calculate_average_tanimoto_similarity(smiles_list_1, smiles_list_2):
    """
    Calculates the average Tanimoto similarity between two lists of SMILES strings.
    
    Parameters:
    - smiles_list_1: A list of SMILES strings.
    - smiles_list_2: Another list of SMILES strings to compare against the first list.
    
    Returns:
    - The average Tanimoto similarity between all pairs of molecules from the two lists.
    """
    # Generate RDKit Mol objects
    mols_1 = [Chem.MolFromSmiles(smile) for smile in smiles_list_1 if smile is not None]
    mols_2 = [Chem.MolFromSmiles(smile) for smile in smiles_list_2 if smile is not None]
    
    # Generate fingerprints
    fps_1 = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024) for mol in mols_1]
    fps_2 = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024) for mol in mols_2]
    
    # Calculate pairwise Tanimoto similarities
    similarity_matrix = []
    for fp1 in fps_1:
        row_similarities = [DataStructs.FingerprintSimilarity(fp1, fp2) for fp2 in fps_2]
        similarity_matrix.append(row_similarities)
    
    # Convert similarity matrix to a numpy array for easier analysis
    similarity_array = np.array(similarity_matrix)
    
    # Compute the average similarity
    average_similarity = similarity_array.mean()
    
    return average_similarity

# %%
nrti_gen = calculate_average_tanimoto_similarity(nrti, valid_smiles)
protease_gen = calculate_average_tanimoto_similarity(protease, valid_smiles)

print(f"Average Tanimoto similarity between generated molecules and NRTIs: {nrti_gen}")
print(f"Average Tanimoto similarity between generated molecules and protease inhibitors: {protease_gen}")
# Out:
# Average Tanimoto similarity between generated molecules and NRTIs: 0.09467775915004666
# Average Tanimoto similarity between generated molecules and protease inhibitors: 0.24659917284397193

# %%
generated_generated = calculate_average_tanimoto_similarity(valid_smiles, valid_smiles)
print(f"Average Tanimoto similarity between generated molecules: {generated_generated}")
# Out:
# Average Tanimoto similarity between generated molecules: 0.22349897654581044

# %%
def ro5_violations(smiles_list):
    """
    Calculates the average number of Lipinski Rule of Five violations for a list of SMILES strings.
    
    Parameters:
    - smiles_list: A list of SMILES strings.
    
    Returns:
    - The average number of Ro5 violations for the molecules in the list.
    """
    # Generate RDKit Mol objects
    mols = [Chem.MolFromSmiles(smile) for smile in smiles_list if smile is not None]
    
    # Calculate the number of violations for each molecule
    violations = [Lipinski.NumHAcceptors(mol) > 10 or Lipinski.NumHDonors(mol) > 5 or Descriptors.MolWt(mol) > 500 or Crippen.MolLogP(mol) > 5 for mol in mols]

    # Calculate the average number of violations
    average_violations = sum(violations) / len(violations)
    
    return average_violations

# %%
gen_lipinski = ro5_violations(valid_smiles)
print(f"Number of Lipinski rule violations: {gen_lipinski}")
# Out:
# Number of Lipinski rule violations: 0.3333333333333333

# %%
# the qed is a quantitative measure of drug-likeness
from rdkit import Chem
from rdkit.Chem import QED



def calculate_qed(smiles_list):
    """
    Calculates the quantitative estimate of drug-likeness (QED) for a list of SMILES strings.

    Parameters:
    - smiles_list: A list of SMILES strings.

    Returns:
    - The average QED for the input molecules.
    """
    # Generate RDKit Mol objects
    mols = [Chem.MolFromSmiles(smile) for smile in smiles_list if smile is not None]

    # Calculate QED values for each molecule
    qed_values = [QED.qed(mol) for mol in mols if mol is not None]

    # Compute the average QED value if there are any valid molecules; otherwise, return 0
    average_qed = sum(qed_values) / len(qed_values) if qed_values else 0

    return average_qed

# %%
gen_qed = calculate_qed(valid_smiles)
print(f"Average QED: {gen_qed}")
# Out:
# Average QED: 0.4123097142929137
